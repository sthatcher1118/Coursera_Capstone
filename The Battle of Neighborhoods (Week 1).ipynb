# %% [markdown]
# <span style="text-align: center">
#
# # Battle of the Neighborhoods (Week 1)
# #### Part of the IBM Data Science Certification: Applied Data Science Capstone, Final Project
#
# </span>
#
# <div style="margin-left: 50px; margin-right: 50px; padding-top: 30px">
#
# <span style="text-align: center">
#
# ## Abstract
#
# </span>
#
# In this work, we will be examining geographical locations from 3 different neighboring areas within northern Virginia. Each area will be divided into equally sized bounding boxes and the types of venues (shops, restaurants, ammenities) will be exmained to find the best fit based on a predetermined set of preferences. This is exercising a content-based recommender algorithm to determine the top `N` (in this case `N = 3`) sections of any of the neighborhoods.
#
# </div>

# %% [markdown]
# ## Table of Contents
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#introduction">Introduction</a>
#
# 1. <a href="#data_description">Data Description</a>
#
# 1. <a href="#methodology">Methodology</a>
#
# 1. <a href="#results">Results</a>
#
# 1. <a href="#t4">Discussion</a>
#
# 1. <a href="#conclusion">Conclusion</a>
#
# </font>
# </div>

# %% [markdown]
# ## Preamble: Imports, Constants, and Functions

# %%
# The code was removed by Watson Studio for sharing.

# %%
# %%capture
# Get stuff installed
# !pip install geocoder
# !pip install foursquare
# !pip install folium
# !pip install wordcloud

import pandas as pd
import numpy as np
# import k-means from clustering stage
from sklearn.cluster import KMeans

# Geo-data
import geocoder
import foursquare
import folium # mapping

# Viz stuff
# Matplotlib and associated plotting modules
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as colors
# %matplotlib inline

# import package and its set of stopwords
from wordcloud import WordCloud, STOPWORDS
stopwords = set(STOPWORDS)


# Watson Studio stuff
from project_lib import Project

# Others
import re
import html
import math

# %%
KM_PER_DEGREE = 111.32
R_EARTH = 6378.1
CHANTILLY = 0
TYSONS = 1
ARLINGTON = 2
ALEXANDRIA = 3
PLACES = pd.DataFrame({
    'id': [CHANTILLY, TYSONS, ARLINGTON, ALEXANDRIA],
    'place': ['Chantilly, VA','Tysons Corner, VA', 'Arlington, VA', 'Alexandria, VA'], 
    'radius-m': [2780, 1660, 4190, 3170]
    })

PLACES = pd.concat([PLACES, pd.DataFrame([geocoder.google(place, key=api_key).latlng for place in PLACES['place']], columns=['lat', 'lng'])], axis=1)
CENTER = PLACES[['lat', 'lng']].mean()
BOUNDS = [list(PLACES[['lat','lng']].min().values), list(PLACES[['lat', 'lng']].max().values)]

FSQ_CLIENT = foursquare.Foursquare(client_id=fsq['id'], client_secret=fsq['sec'], version=fsq['ver'])
PROJECT = Project(None, proj['id'], proj['token'])

SURVEY = pd.read_csv('Survey.csv')

print(f'This notebooks is part of the \'{PROJECT.get_name()}\' project')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-ce60a2997c01> in <module>
#      18 PROJECT = Project(None, proj['id'], proj['token'])
#      19
# ---> 20 SURVEY = pd.read_csv('Survey.csv')
#      21
#      22 print(f'This notebooks is part of the \'{PROJECT.get_name()}\' project')
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# /opt/conda/envs/Python36/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'Survey.csv' does not exist: b'Survey.csv'

# %% [markdown]
# <a id="introduction"></a>
#
# ## Introduction
#
# ACME, Inc. is a growing company currently located in Chantilly, Virginia. Due to their growth, they need to relocate to a larger office and have decided to relocate closer to Washington, D.C. in response to their employees' preference. The owners of ACME, Inc. have determined that *Tysons Corner*, *Arlington*, or *Alexandria* would be all be viable locations for their new office. However, determining a specific location has become an issue.
#
# In order to improve their employees' work experience, they issued an employee-wide survey to determine the types of venues, shops, restaurants or other ammenities that need to be near the new location (within approximately 500 meters or about 5 minutes walk).

# %%
map = folium.Map(location=CENTER, zoom_control=False)
map.fit_bounds(BOUNDS)
for _, row in PLACES[['lat', 'lng', 'radius-m']].iterrows():
    folium.vector_layers.Circle(location=(row.loc['lat'], row.loc['lng']), radius=row.loc['radius-m'], fill=True, color='red' if _ == 0 else 'blue').add_to(map)
    
for _, row in SITES.iterrows():
    folium.map.Marker([row.loc['lat'], row.loc['lng']]).add_to(map)
    folium.vector_layers.Circle([row.loc['lat'], row.loc['lng']], radius=500, color='black').add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
tysons = PLACES[['lat','lng']].iloc[1,:].values
tysons = f'{tysons[0]},{tysons[1]}'

# %%
tysons
t_venues = FSQ_CLIENT.venues.explore(params={'ll': tysons, 'radius': 1660, 'limit': 1000, 'time': 'any'})

# %%
t_venues
# Out:
# {'suggestedFilters': {'header': 'Tap to show:',
#   'filters': [{'name': 'Open now', 'key': 'openNow'},
#    {'name': '$-$$$$', 'key': 'price'}]},
#  'headerLocation': 'Tysons Corner',
#  'headerFullLocation': 'Tysons Corner',
#  'headerLocationGranularity': 'city',
#  'totalResults': 144,
#  'suggestedBounds': {'ne': {'lat': 38.933662214940014,
#    'lng': -77.21192618431388},
#   'sw': {'lat': 38.90378218505998, 'lng': -77.25025881568612}},
#  'groups': [{'type': 'Recommended Places',
#    'name': 'recommended',
#    'items': [{'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '51891fea498ee05ee808e258',
#       'name': 'REI',
#       'location': {'address': '8209 Watson Street',
#        'lat': 38.9183498,
#        'lng': -77.2288267,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.9183498,
#          'lng': -77.2288267}],
#        'distance': 200,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8209 Watson Street',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1f2941735',
#         'name': 'Sporting Goods Shop',
#         'pluralName': 'Sporting Goods Shops',
#         'shortName': 'Sporting Goods',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-51891fea498ee05ee808e258-0'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4cd1b5b606b546881d3ce294',
#       'name': 'Super Chicken',
#       'location': {'address': '8357 Leesburg Pike',
#        'lat': 38.92057501898031,
#        'lng': -77.23507501067621,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.92057501898031,
#          'lng': -77.23507501067621},
#         {'label': '?', 'lat': 38.920744, 'lng': -77.234941}],
#        'distance': 401,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8357 Leesburg Pike',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1cd941735',
#         'name': 'South American Restaurant',
#         'pluralName': 'South American Restaurants',
#         'shortName': 'South American',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4cd1b5b606b546881d3ce294-1'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '568441df498eed21c59b25de',
#       'name': 'Roll Play',
#       'location': {'address': '8150 Leesburg Pike Ste 100',
#        'lat': 38.9161359092294,
#        'lng': -77.22733668241158,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.9161359092294,
#          'lng': -77.22733668241158}],
#        'distance': 434,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8150 Leesburg Pike Ste 100',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d14a941735',
#         'name': 'Vietnamese Restaurant',
#         'pluralName': 'Vietnamese Restaurants',
#         'shortName': 'Vietnamese',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#          'suffix': '.png'},
#         'primary': True}],
#       'delivery': {'id': '1097452',
#        'url': 'https://www.grubhub.com/restaurant/roll-play-grill-8150-leesburg-pike-ste-100-vienna/1097452?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1097452',
#        'provider': {'name': 'grubhub',
#         'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#          'sizes': [40, 50],
#          'name': '/delivery_provider_grubhub_20180129.png'}}},
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-568441df498eed21c59b25de-2'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4a63e6acf964a520fbc51fe3',
#       'name': 'Sakura Japanese Steak, Seafood House & Sushi Bar',
#       'location': {'address': '8369 Leesburg Pike',
#        'lat': 38.921471099535665,
#        'lng': -77.2357745391068,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.921471099535665,
#          'lng': -77.2357745391068},
#         {'label': '?', 'lat': 38.922497, 'lng': -77.2376}],
#        'distance': 508,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8369 Leesburg Pike',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1d2941735',
#         'name': 'Sushi Restaurant',
#         'pluralName': 'Sushi Restaurants',
#         'shortName': 'Sushi',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '343907805'}},
#      'referralId': 'e-0-4a63e6acf964a520fbc51fe3-3'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b8323eff964a520f1f930e3',
#       'name': "Fleming's Prime Steakhouse & Wine Bar",
#       'location': {'address': '1960A Chain Bridge Rd',
#        'crossStreet': 'at International Dr.',
#        'lat': 38.92055692262671,
#        'lng': -77.22706827218464,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.92055692262671,
#          'lng': -77.22706827218464}],
#        'distance': 403,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1960A Chain Bridge Rd (at International Dr.)',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1cc941735',
#         'name': 'Steakhouse',
#         'pluralName': 'Steakhouses',
#         'shortName': 'Steakhouse',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b8323eff964a520f1f930e3-4'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '547bf26b498ea3fb9947b0cb',
#       'name': 'Esthetic Institute',
#       'location': {'address': '8381 Old Courthouse Rd',
#        'lat': 38.91434,
#        'lng': -77.23416,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.91434,
#          'lng': -77.23416},
#         {'label': '?', 'lat': 38.91449, 'lng': -77.234071}],
#        'distance': 555,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8381 Old Courthouse Rd',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d13b941735',
#         'name': 'School',
#         'pluralName': 'Schools',
#         'shortName': 'School',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/school_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-547bf26b498ea3fb9947b0cb-5'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b9bbb08f964a520ca1e36e3',
#       'name': 'Bed Bath & Beyond',
#       'location': {'address': '2051 Chain Bridge Rd',
#        'lat': 38.9163119,
#        'lng': -77.2340414,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.9163119,
#          'lng': -77.2340414}],
#        'distance': 370,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['2051 Chain Bridge Rd',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1f8941735',
#         'name': 'Furniture / Home Store',
#         'pluralName': 'Furniture / Home Stores',
#         'shortName': 'Furniture / Home',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b9bbb08f964a520ca1e36e3-6'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4f626ea7e4b0ea77cba053b8',
#       'name': 'CAVA',
#       'location': {'address': '8048 Tysons Corner Ctr',
#        'lat': 38.9171941,
#        'lng': -77.2236294,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.9171941,
#          'lng': -77.2236294}],
#        'distance': 668,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8048 Tysons Corner Ctr',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1c0941735',
#         'name': 'Mediterranean Restaurant',
#         'pluralName': 'Mediterranean Restaurants',
#         'shortName': 'Mediterranean',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mediterranean_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4f626ea7e4b0ea77cba053b8-7'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5dd831fed892900007dfa839',
#       'name': 'Shotted Specialty Coffee',
#       'location': {'address': '1961 Chain Bridge Rd',
#        'lat': 38.917435,
#        'lng': -77.223452,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.917435,
#          'lng': -77.223452}],
#        'distance': 677,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1961 Chain Bridge Rd',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-5dd831fed892900007dfa839-8'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '59a5873fd3cce87c7c6cab7a',
#       'name': 'DoubleTree by Hilton',
#       'location': {'address': '1960 Chain Bridge Rd',
#        'lat': 38.920667,
#        'lng': -77.227136,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.920667,
#          'lng': -77.227136}],
#        'distance': 405,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1960 Chain Bridge Rd',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1fa931735',
#         'name': 'Hotel',
#         'pluralName': 'Hotels',
#         'shortName': 'Hotel',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-59a5873fd3cce87c7c6cab7a-9'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '556f29c9498e3489675bdba8',
#       'name': 'Kizuna',
#       'location': {'address': '8221 Leesburg Pike',
#        'lat': 38.91673937095451,
#        'lng': -77.22942564565031,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.91673937095451,
#          'lng': -77.22942564565031}],
#        'distance': 263,
#        'postalCode': '22182',
#        'cc': 'US',
#        'neighborhood': 'Northwest Old Courthouse',
#        'city': 'Tysons Corner',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8221 Leesburg Pike',
#         'Tysons Corner, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1d2941735',
#         'name': 'Sushi Restaurant',
#         'pluralName': 'Sushi Restaurants',
#         'shortName': 'Sushi',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#          'suffix': '.png'},
#         'primary': True}],
#       'delivery': {'id': '439088',
#        'url': 'https://www.grubhub.com/restaurant/kizuna-sushi--ramen-8221-leesburg-pike-vienna/439088?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=439088',
#        'provider': {'name': 'grubhub',
#         'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#          'sizes': [40, 50],
#          'name': '/delivery_provider_grubhub_20180129.png'}}},
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-556f29c9498e3489675bdba8-10'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5a1375b246e1b62527257ae3',
#       'name': '&pizza',
#       'location': {'address': '1961 Chain Bridge Rd',
#        'lat': 38.9170244,
#        'lng': -77.2238354,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.9170244,
#          'lng': -77.2238354}],
#        'distance': 656,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1961 Chain Bridge Rd',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1ca941735',
#         'name': 'Pizza Place',
#         'pluralName': 'Pizza Places',
#         'shortName': 'Pizza',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-5a1375b246e1b62527257ae3-11'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4a608daaf964a520ddc01fe3',
#       'name': 'Apple Tysons Corner',
#       'location': {'address': '1961 Chain Bridge Road',
#        'crossStreet': 'at Tysons Corner Center',
#        'lat': 38.9168926,
#        'lng': -77.2229982,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.9168926,
#          'lng': -77.2229982}],
#        'distance': 730,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1961 Chain Bridge Road (at Tysons Corner Center)',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d122951735',
#         'name': 'Electronics Store',
#         'pluralName': 'Electronics Stores',
#         'shortName': 'Electronics',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#          'suffix': '.png'},
#         'primary': True}],
#       'delivery': {'id': '1408590',
#        'url': 'https://www.grubhub.com/restaurant/pizza-tysons-corner-1961-chain-bridge-rd-mc-lean/1408590?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1408590',
#        'provider': {'name': 'grubhub',
#         'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#          'sizes': [40, 50],
#          'name': '/delivery_provider_grubhub_20180129.png'}}},
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4a608daaf964a520ddc01fe3-12'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4a884830f964a520b80520e3',
#       'name': 'Neiman Marcus',
#       'location': {'address': '2255 International Dr',
#        'lat': 38.92284107766551,
#        'lng': -77.2242835676921,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.92284107766551,
#          'lng': -77.2242835676921}],
#        'distance': 746,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['2255 International Dr',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1f6941735',
#         'name': 'Department Store',
#         'pluralName': 'Department Stores',
#         'shortName': 'Department Store',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4a884830f964a520b80520e3-13'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b30a8abf964a520b6fa24e3',
#       'name': 'Tysons Sport&Health',
#       'location': {'address': '8250 Greensboro Dr',
#        'lat': 38.92328633177138,
#        'lng': -77.2301691770553,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.92328633177138,
#          'lng': -77.2301691770553}],
#        'distance': 514,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8250 Greensboro Dr',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d175941735',
#         'name': 'Gym / Fitness Center',
#         'pluralName': 'Gyms or Fitness Centers',
#         'shortName': 'Gym / Fitness',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b30a8abf964a520b6fa24e3-14'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4ae3a5e6f964a520a99721e3',
#       'name': 'Nordstrom',
#       'location': {'address': '8075 Tysons Corner Ctr',
#        'lat': 38.9169534,
#        'lng': -77.2218155,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.9169534,
#          'lng': -77.2218155}],
#        'distance': 827,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8075 Tysons Corner Ctr',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d108951735',
#         'name': "Women's Store",
#         'pluralName': "Women's Stores",
#         'shortName': "Women's Store",
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4ae3a5e6f964a520a99721e3-15'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5c0ab2eb0d173f002c14666f',
#       'name': 'Sen Khao',
#       'location': {'address': '2001 International Dr',
#        'lat': 38.92419734406828,
#        'lng': -77.22444777679523,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.92419734406828,
#          'lng': -77.22444777679523}],
#        'distance': 838,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['2001 International Dr',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d149941735',
#         'name': 'Thai Restaurant',
#         'pluralName': 'Thai Restaurants',
#         'shortName': 'Thai',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-5c0ab2eb0d173f002c14666f-16'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '50e5a665e4b0fa1531dedc85',
#       'name': 'PAUL',
#       'location': {'address': '2001 International Dr #1856G',
#        'crossStreet': "Tyson's Galleria",
#        'lat': 38.923325787290956,
#        'lng': -77.22486377068878,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.923325787290956,
#          'lng': -77.22486377068878}],
#        'distance': 744,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ["2001 International Dr #1856G (Tyson's Galleria)",
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d16a941735',
#         'name': 'Bakery',
#         'pluralName': 'Bakeries',
#         'shortName': 'Bakery',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-50e5a665e4b0fa1531dedc85-17'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b55be47f964a52006ee27e3',
#       'name': 'Tysons Galleria',
#       'location': {'address': '2001 International Dr',
#        'lat': 38.923826924528576,
#        'lng': -77.22456490436232,
#        'distance': 801,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['2001 International Dr',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1fd941735',
#         'name': 'Shopping Mall',
#         'pluralName': 'Shopping Malls',
#         'shortName': 'Mall',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b55be47f964a52006ee27e3-18'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b3833fff964a520ca4c25e3',
#       'name': 'Saks Fifth Avenue',
#       'location': {'address': '2051 International Dr',
#        'lat': 38.92394289,
#        'lng': -77.2250739,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.92394289,
#          'lng': -77.2250739}],
#        'distance': 780,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['2051 International Dr',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1f6941735',
#         'name': 'Department Store',
#         'pluralName': 'Department Stores',
#         'shortName': 'Department Store',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '567670500'}},
#      'referralId': 'e-0-4b3833fff964a520ca4c25e3-19'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4dbea8325da3ff58ec7eabd7',
#       'name': 'Nostos',
#       'location': {'address': '8100 Boone Blvd',
#        'lat': 38.91365262589009,
#        'lng': -77.22550074249726,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.91365262589009,
#          'lng': -77.22550074249726}],
#        'distance': 743,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8100 Boone Blvd',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d10e941735',
#         'name': 'Greek Restaurant',
#         'pluralName': 'Greek Restaurants',
#         'shortName': 'Greek',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4dbea8325da3ff58ec7eabd7-20'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '57811712498e6f91f674b4f7',
#       'name': 'Kung Fu Tea',
#       'location': {'address': '1961 Chain Bridge Road, Kiosk #SKS01',
#        'lat': 38.918017,
#        'lng': -77.2229488,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.918017,
#          'lng': -77.2229488}],
#        'distance': 709,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1961 Chain Bridge Road, Kiosk #SKS01',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#         'name': 'Bubble Tea Shop',
#         'pluralName': 'Bubble Tea Shops',
#         'shortName': 'Bubble Tea',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#          'suffix': '.png'},
#         'primary': True}],
#       'delivery': {'id': '1961709',
#        'url': 'https://www.grubhub.com/restaurant/kung-fu-tea-1961-chain-bridge-rd-mclean/1961709?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1961709',
#        'provider': {'name': 'grubhub',
#         'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#          'sizes': [40, 50],
#          'name': '/delivery_provider_grubhub_20180129.png'}}},
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-57811712498e6f91f674b4f7-21'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b1a67fcf964a520eee923e3',
#       'name': 'The Cheesecake Factory',
#       'location': {'address': '1796 International Dr',
#        'crossStreet': 'at Tysons Galleria',
#        'lat': 38.923281267800796,
#        'lng': -77.22514174871779,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.923281267800796,
#          'lng': -77.22514174871779}],
#        'distance': 723,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1796 International Dr (at Tysons Galleria)',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d14e941735',
#         'name': 'American Restaurant',
#         'pluralName': 'American Restaurants',
#         'shortName': 'American',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b1a67fcf964a520eee923e3-22'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4bda11db2a3a0f47b49ca9b6',
#       'name': "Danielle's Desserts",
#       'location': {'lat': 38.92402573592962,
#        'lng': -77.2245756695197,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.92402573592962,
#          'lng': -77.2245756695197}],
#        'distance': 816,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'Mc Lean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['Mc Lean, VA 22102', 'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1bc941735',
#         'name': 'Cupcake Shop',
#         'pluralName': 'Cupcake Shops',
#         'shortName': 'Cupcakes',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cupcakes_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4bda11db2a3a0f47b49ca9b6-23'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '52817f6a11d2aa8bc6099ad7',
#       'name': 'CVS pharmacy',
#       'location': {'address': '8117 Leesburg Pike',
#        'crossStreet': 'Gallows Rd',
#        'lat': 38.91507200794992,
#        'lng': -77.2263425449979,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.91507200794992,
#          'lng': -77.2263425449979}],
#        'distance': 578,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8117 Leesburg Pike (Gallows Rd)',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d10f951735',
#         'name': 'Pharmacy',
#         'pluralName': 'Pharmacies',
#         'shortName': 'Pharmacy',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-52817f6a11d2aa8bc6099ad7-24'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4a2aa4fdf964a5202e961fe3',
#       'name': 'Panera Bread',
#       'location': {'address': '8365 Leesburg Pike',
#        'lat': 38.9209353,
#        'lng': -77.2360327,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.9209353,
#          'lng': -77.2360327}],
#        'distance': 493,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8365 Leesburg Pike',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d16a941735',
#         'name': 'Bakery',
#         'pluralName': 'Bakeries',
#         'shortName': 'Bakery',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4a2aa4fdf964a5202e961fe3-25'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '49c319a5f964a52057561fe3',
#       'name': 'Tysons Corner Center',
#       'location': {'address': '1961 Chain Bridge Rd',
#        'lat': 38.91780165978919,
#        'lng': -77.22103941939764,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.91780165978919,
#          'lng': -77.22103941939764}],
#        'distance': 876,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'Tysons',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1961 Chain Bridge Rd',
#         'Tysons, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1fd941735',
#         'name': 'Shopping Mall',
#         'pluralName': 'Shopping Malls',
#         'shortName': 'Mall',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mall_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '56301890'}},
#      'referralId': 'e-0-49c319a5f964a52057561fe3-26'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4ac23505f964a5202f9820e3',
#       'name': "P.F. Chang's",
#       'location': {'address': '1716M International Dr',
#        'crossStreet': "at Tyson's Galleria",
#        'lat': 38.924443,
#        'lng': -77.225382,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.924443,
#          'lng': -77.225382}],
#        'distance': 806,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ["1716M International Dr (at Tyson's Galleria)",
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d145941735',
#         'name': 'Chinese Restaurant',
#         'pluralName': 'Chinese Restaurants',
#         'shortName': 'Chinese',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4ac23505f964a5202f9820e3-27'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b5b8806f964a520250529e3',
#       'name': 'Louis Vuitton',
#       'location': {'address': '2255 International Dr',
#        'crossStreet': 'at Tysons Galleria',
#        'lat': 38.924005307312775,
#        'lng': -77.22444390253153,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.924005307312775,
#          'lng': -77.22444390253153}],
#        'distance': 823,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['2255 International Dr (at Tysons Galleria)',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d104951735',
#         'name': 'Boutique',
#         'pluralName': 'Boutiques',
#         'shortName': 'Boutique',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_boutique_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b5b8806f964a520250529e3-28'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '54c53d93498e753931b3471c',
#       'name': 'Founding Farmers',
#       'location': {'address': '1800 Tysons Blvd',
#        'lat': 38.92287789582031,
#        'lng': -77.22231682838377,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.92287789582031,
#          'lng': -77.22231682838377}],
#        'distance': 889,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'Tysons',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1800 Tysons Blvd',
#         'Tysons, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d14e941735',
#         'name': 'American Restaurant',
#         'pluralName': 'American Restaurants',
#         'shortName': 'American',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'delivery': {'id': '1134146',
#        'url': 'https://www.grubhub.com/restaurant/founding-farmers-1800-tysons-blvd-mc-lean/1134146?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1134146',
#        'provider': {'name': 'grubhub',
#         'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#          'sizes': [40, 50],
#          'name': '/delivery_provider_grubhub_20180129.png'}}},
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-54c53d93498e753931b3471c-29'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5907c89226659b275bd837e1',
#       'name': "Teas'n You Fusion Tea House",
#       'location': {'address': '8032 Leesburg Pike Ste E',
#        'crossStreet': 'Towers Crescent Drive',
#        'lat': 38.91388935240539,
#        'lng': -77.22277588121918,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.91388935240539,
#          'lng': -77.22277588121918}],
#        'distance': 899,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8032 Leesburg Pike Ste E (Towers Crescent Drive)',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '52e81612bcbc57f1066b7a0c',
#         'name': 'Bubble Tea Shop',
#         'pluralName': 'Bubble Tea Shops',
#         'shortName': 'Bubble Tea',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-5907c89226659b275bd837e1-30'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '50cb7808e4b00957c1b2e2a8',
#       'name': 'Le Pain Quotidien',
#       'location': {'address': '1961 Chain Bridge Rd',
#        'lat': 38.9160295,
#        'lng': -77.2230154,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.9160295,
#          'lng': -77.2230154}],
#        'distance': 761,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'Tysons Corner',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1961 Chain Bridge Rd',
#         'Tysons Corner, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d143941735',
#         'name': 'Breakfast Spot',
#         'pluralName': 'Breakfast Spots',
#         'shortName': 'Breakfast',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/breakfast_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-50cb7808e4b00957c1b2e2a8-31'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b49118ff964a5208a6426e3',
#       'name': 'Disney Store',
#       'location': {'address': '1961 Chain Bridge Road',
#        'crossStreet': 'at International Dr',
#        'lat': 38.918316,
#        'lng': -77.222398,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.918316,
#          'lng': -77.222398}],
#        'distance': 754,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1961 Chain Bridge Road (at International Dr)',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1f3941735',
#         'name': 'Toy / Game Store',
#         'pluralName': 'Toy / Game Stores',
#         'shortName': 'Toys & Games',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/toys_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b49118ff964a5208a6426e3-32'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b379d52f964a5200f4325e3',
#       'name': "Bloomingdale's",
#       'location': {'address': '8100 Tysons Corner Center',
#        'crossStreet': 'in Tysons Corner Center',
#        'lat': 38.915953,
#        'lng': -77.223772,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.915953,
#          'lng': -77.223772}],
#        'distance': 705,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8100 Tysons Corner Center (in Tysons Corner Center)',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1f6941735',
#         'name': 'Department Store',
#         'pluralName': 'Department Stores',
#         'shortName': 'Department Store',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/departmentstore_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b379d52f964a5200f4325e3-33'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '529ccc3411d276939f19f312',
#       'name': 'sweetgreen',
#       'location': {'address': '1743 International Drive',
#        'lat': 38.9246953,
#        'lng': -77.2248145,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.9246953,
#          'lng': -77.2248145}],
#        'distance': 858,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1743 International Drive',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1bd941735',
#         'name': 'Salad Place',
#         'pluralName': 'Salad Places',
#         'shortName': 'Salad',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-529ccc3411d276939f19f312-34'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '55fb0d3c498e057977b916c2',
#       'name': 'Hyatt Regency Tysons Corner Center',
#       'location': {'address': '7901 Tysons One Pl',
#        'lat': 38.91864939389951,
#        'lng': -77.22007616515943,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.91864939389951,
#          'lng': -77.22007616515943}],
#        'distance': 954,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'Tysons Corner',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['7901 Tysons One Pl',
#         'Tysons Corner, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1fa931735',
#         'name': 'Hotel',
#         'pluralName': 'Hotels',
#         'shortName': 'Hotel',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-55fb0d3c498e057977b916c2-35'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b566252f964a520220e28e3',
#       'name': 'Starbucks',
#       'location': {'address': '8381 Leesburg Pike',
#        'crossStreet': 'at Gosnell Rd',
#        'lat': 38.921646,
#        'lng': -77.236275,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.921646,
#          'lng': -77.236275},
#         {'label': '?', 'lat': 38.922687, 'lng': -77.237643}],
#        'distance': 554,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8381 Leesburg Pike (at Gosnell Rd)',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b566252f964a520220e28e3-36'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b92725ef964a52032fa33e3',
#       'name': 'Equinox Tysons Corner',
#       'location': {'address': '8065 Leesburg Pike',
#        'crossStreet': 'at Fairfax Square',
#        'lat': 38.912601,
#        'lng': -77.224865,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.912601,
#          'lng': -77.224865}],
#        'distance': 869,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8065 Leesburg Pike (at Fairfax Square)',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d176941735',
#         'name': 'Gym',
#         'pluralName': 'Gyms',
#         'shortName': 'Gym',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b92725ef964a52032fa33e3-37'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5d8b6ea5767433000802c262',
#       'name': 'Whole Foods Market',
#       'location': {'address': '1635 Boro Pl',
#        'lat': 38.924832,
#        'lng': -77.233269,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.924832,
#          'lng': -77.233269}],
#        'distance': 705,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1635 Boro Pl',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d118951735',
#         'name': 'Grocery Store',
#         'pluralName': 'Grocery Stores',
#         'shortName': 'Grocery Store',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#          'suffix': '.png'},
# ...
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4afc43c7f964a520002122e3',
#       'name': 'The Palm',
#       'location': {'address': '1750 Tysons Blvd',
#        'crossStreet': 'at International Dr',
#        'lat': 38.9237747,
#        'lng': -77.2229517,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.9237747,
#          'lng': -77.2229517}],
#        'distance': 901,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1750 Tysons Blvd (at International Dr)',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1cc941735',
#         'name': 'Steakhouse',
#         'pluralName': 'Steakhouses',
#         'shortName': 'Steakhouse',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4afc43c7f964a520002122e3-87'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b50f8eaf964a5204b3b27e3',
#       'name': "Ruth's Chris Steak House",
#       'location': {'address': '8521 Leesburg Pike, Tysons Corner',
#        'lat': 38.92649002882151,
#        'lng': -77.24021992181406,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.92649002882151,
#          'lng': -77.24021992181406}],
#        'distance': 1171,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8521 Leesburg Pike, Tysons Corner',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1cc941735',
#         'name': 'Steakhouse',
#         'pluralName': 'Steakhouses',
#         'shortName': 'Steakhouse',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/steakhouse_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b50f8eaf964a5204b3b27e3-88'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4a980cc3f964a5203d2a20e3',
#       'name': 'Barnes & Noble',
#       'location': {'address': '7851L Tysons Corner Ctr',
#        'lat': 38.91747988372015,
#        'lng': -77.21845637107174,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.91747988372015,
#          'lng': -77.21845637107174}],
#        'distance': 1103,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['7851L Tysons Corner Ctr',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d114951735',
#         'name': 'Bookstore',
#         'pluralName': 'Bookstores',
#         'shortName': 'Bookstore',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4a980cc3f964a5203d2a20e3-89'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5a36da5c112c6c3d64f6168f',
#       'name': 'Lady M Pop-Up',
#       'location': {'lat': 38.92442443597302,
#        'lng': -77.22474641530859,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.92442443597302,
#          'lng': -77.22474641530859}],
#        'distance': 839,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['McLean, VA 22102', 'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1d0941735',
#         'name': 'Dessert Shop',
#         'pluralName': 'Dessert Shops',
#         'shortName': 'Desserts',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-5a36da5c112c6c3d64f6168f-90'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b32821ef964a5206c0d25e3',
#       'name': 'Starbucks',
#       'location': {'address': '2001 International Dr',
#        'crossStreet': 'at Tysons Galleria',
#        'lat': 38.92358466375955,
#        'lng': -77.2243403543175,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.92358466375955,
#          'lng': -77.2243403543175}],
#        'distance': 796,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['2001 International Dr (at Tysons Galleria)',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b32821ef964a5206c0d25e3-91'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4c5313921b46c9b6c42b60cc',
#       'name': 'T-Mobile',
#       'location': {'address': '8045L Tysons Corner Ctr',
#        'lat': 38.91729367,
#        'lng': -77.22258933,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.91729367,
#          'lng': -77.22258933}],
#        'distance': 753,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8045L Tysons Corner Ctr',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4f04afc02fb6e1c99f3db0bc',
#         'name': 'Mobile Phone Shop',
#         'pluralName': 'Mobile Phone Shops',
#         'shortName': 'Mobile Phones',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/mobilephoneshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4c5313921b46c9b6c42b60cc-92'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b115bb9f964a520db7a23e3',
#       'name': 'Modern Nail Studio',
#       'location': {'address': '7858 Tysons Corner Ctr',
#        'lat': 38.918126895856496,
#        'lng': -77.21872920814077,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.918126895856496,
#          'lng': -77.21872920814077}],
#        'distance': 1072,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['7858 Tysons Corner Ctr',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1ed941735',
#         'name': 'Spa',
#         'pluralName': 'Spas',
#         'shortName': 'Spa',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b115bb9f964a520db7a23e3-93'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4eb51e62b8f786e2750cb6b7',
#       'name': 'Microsoft Store',
#       'location': {'address': '1961 Chain Bridge Rd',
#        'lat': 38.91797235196003,
#        'lng': -77.22066812858768,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.91797235196003,
#          'lng': -77.22066812858768}],
#        'distance': 906,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'Tysons Corner',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1961 Chain Bridge Rd',
#         'Tysons Corner, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d122951735',
#         'name': 'Electronics Store',
#         'pluralName': 'Electronics Stores',
#         'shortName': 'Electronics',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4eb51e62b8f786e2750cb6b7-94'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5ba92adb16ef6700390dfda3',
#       'name': 'honeygrow',
#       'location': {'address': '8399 Leesburg Pike',
#        'lat': 38.923286,
#        'lng': -77.236818,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.923286,
#          'lng': -77.236818}],
#        'distance': 709,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8399 Leesburg Pike',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1d1941735',
#         'name': 'Noodle House',
#         'pluralName': 'Noodle Houses',
#         'shortName': 'Noodles',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/ramen_',
#          'suffix': '.png'},
#         'primary': True}],
#       'delivery': {'id': '1246025',
#        'url': 'https://www.grubhub.com/restaurant/honeygrow-8399-leesburg-pike-vienna/1246025?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1246025',
#        'provider': {'name': 'grubhub',
#         'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#          'sizes': [40, 50],
#          'name': '/delivery_provider_grubhub_20180129.png'}}},
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-5ba92adb16ef6700390dfda3-95'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b23bd9df964a520e15824e3',
#       'name': 'Anthropologie',
#       'location': {'address': '2001 International Dr',
#        'lat': 38.924562393271486,
#        'lng': -77.22484381184887,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.924562393271486,
#          'lng': -77.22484381184887}],
#        'distance': 845,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'McLean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['2001 International Dr',
#         'McLean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d108951735',
#         'name': "Women's Store",
#         'pluralName': "Women's Stores",
#         'shortName': "Women's Store",
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_women_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-4b23bd9df964a520e15824e3-96'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '505367d2e4b058885119e5b4',
#       'name': 'Tysons Corner Metro Station',
#       'location': {'address': '1943 Chain Bridge Rd',
#        'crossStreet': 'Tysons Blvd',
#        'lat': 38.92044684686478,
#        'lng': -77.22177037739041,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.92044684686478,
#          'lng': -77.22177037739041}],
#        'distance': 829,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'Tysons Corner',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['1943 Chain Bridge Rd (Tysons Blvd)',
#         'Tysons Corner, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1fd931735',
#         'name': 'Metro Station',
#         'pluralName': 'Metro Stations',
#         'shortName': 'Metro',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '37501183'}},
#      'referralId': 'e-0-505367d2e4b058885119e5b4-97'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '525ad67e11d2962651aabf16',
#       'name': "BJ's Restaurant & Brewhouse",
#       'location': {'address': '8027 Leesburg Pike',
#        'lat': 38.9125518666677,
#        'lng': -77.2226132766632,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.9125518666677,
#          'lng': -77.2226132766632}],
#        'distance': 1005,
#        'postalCode': '22182',
#        'cc': 'US',
#        'city': 'Vienna',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['8027 Leesburg Pike',
#         'Vienna, VA 22182',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d14e941735',
#         'name': 'American Restaurant',
#         'pluralName': 'American Restaurants',
#         'shortName': 'American',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#          'suffix': '.png'},
#         'primary': True}],
#       'delivery': {'id': '472679',
#        'url': 'https://www.grubhub.com/restaurant/bjs-restaurant-and-brewhouse-8027-leesburg-pike-suite-100-vienna/472679?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=472679',
#        'provider': {'name': 'grubhub',
#         'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#          'sizes': [40, 50],
#          'name': '/delivery_provider_grubhub_20180129.png'}}},
#       'photos': {'count': 0, 'groups': []},
#       'venuePage': {'id': '559365738'}},
#      'referralId': 'e-0-525ad67e11d2962651aabf16-98'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5b22aa523260db00293f8de3',
#       'name': 'Republik Coffee Bar',
#       'location': {'address': '7915 Jones Branch Dr',
#        'lat': 38.926907602667136,
#        'lng': -77.21737574197907,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 38.926907602667136,
#          'lng': -77.21737574197907}],
#        'distance': 1497,
#        'postalCode': '22102',
#        'cc': 'US',
#        'city': 'Mc Lean',
#        'state': 'VA',
#        'country': 'United States',
#        'formattedAddress': ['7915 Jones Branch Dr',
#         'Mc Lean, VA 22102',
#         'United States']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'photos': {'count': 0, 'groups': []}},
#      'referralId': 'e-0-5b22aa523260db00293f8de3-99'}]}]}

# %%
import json
project = Project(None, 'b4b6e557-186a-403e-b446-c7b826c1c3d4', 'p-e999860364eab6c53f34c62a9d8585eeb600df6d')
project.save_data('test.json', data=json.dumps(t_venues))
# Out:
# {'file_name': 'test.json',
#  'message': 'File saved to project storage.',
#  'bucket_name': 'courseradatasciencecertification-donotdelete-pr-rlttrl1sp7ama1',
#  'asset_id': 'ef73151f-5478-47a6-8fe9-6d2ca910a0f8'}

# %%
[print(v['venue']) for v in t_venues['groups'][0]['items'] if v['venue']['categories'] and v['venue']['categories'][0]['name'] == 'Metro Station']
# Out:
# {'id': '505367d2e4b058885119e5b4', 'name': 'Tysons Corner Metro Station', 'location': {'address': '1943 Chain Bridge Rd', 'crossStreet': 'Tysons Blvd', 'lat': 38.92044684686478, 'lng': -77.22177037739041, 'labeledLatLngs': [{'label': 'display', 'lat': 38.92044684686478, 'lng': -77.22177037739041}], 'distance': 829, 'postalCode': '22102', 'cc': 'US', 'city': 'Tysons Corner', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['1943 Chain Bridge Rd (Tysons Blvd)', 'Tysons Corner, VA 22102', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d1fd931735', 'name': 'Metro Station', 'pluralName': 'Metro Stations', 'shortName': 'Metro', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/subway_', 'suffix': '.png'}, 'primary': True}], 'photos': {'count': 0, 'groups': []}, 'venuePage': {'id': '37501183'}}
# [None]

# %%
[print(cat) for cat in cats]
# Out:
# Adult Boutique
# Animal Shelter
# Auto Dealership
# Bakery
# Bank
# Boutique
# Building
# Business Service
# Café
# Car Wash
# Chiropractor
# Cocktail Bar
# College Classroom
# Conference Room
# Coworking Space
# Deli / Bodega
# Dentist's Office
# Doctor's Office
# Electronics Store
# Event Space
# Eye Doctor
# Financial or Legal Service
# Flower Shop
# Food
# Food Truck
# General Entertainment
# Government Building
# Gym
# Gym / Fitness Center
# Hookah Bar
# Hotel
# IT Services
# Italian Restaurant
# Korean Restaurant
# Laundry Service
# Liquor Store
# Lounge
# Mattress Store
# Medical Center
# Meeting Room
# Men's Store
# Office
# Persian Restaurant
# Pilates Studio
# Residential Building (Apartment / Condo)
# Shopping Mall
# Spiritual Center
# Sporting Goods Shop
# Sushi Restaurant
# Taxi
# Tech Startup
# Travel & Transport
# Urgent Care Center
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
v_cats = [venue for venue in t_venues['venues'] if len(venue['categories']) > 0]

# %%
[print(venue) for venue in v_cats if 'Transport' in venue['categories'][0]['name']]
# Out:
# {'id': '4e91bb7061afcfde2a582a7d', 'name': 'Parking Garage @ Hilton Garden Inn', 'location': {'lat': 38.916551853142764, 'lng': -77.2327270085821, 'labeledLatLngs': [{'label': 'display', 'lat': 38.916551853142764, 'lng': -77.2327270085821}], 'distance': 280, 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['Vienna, VA', 'United States']}, 'categories': [{'id': '4d4b7105d754a06379d81259', 'name': 'Travel & Transport', 'pluralName': 'Travel & Transport', 'shortName': 'Travel', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# [None]

# %%
[print(venue) for venue in v_cats if 'Office' in venue['categories'][0]['name']]
# Out:
# {'id': '5cf655eda22db7002cc97536', 'name': 'David Chow, MD, MPH, FACS', 'location': {'address': '8330 Boone Blvd Ste 160', 'lat': 38.9172564, 'lng': -77.2328814, 'labeledLatLngs': [{'label': 'display', 'lat': 38.9172564, 'lng': -77.2328814}], 'distance': 225, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8330 Boone Blvd Ste 160', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d177941735', 'name': "Doctor's Office", 'pluralName': "Doctor's Offices", 'shortName': "Doctor's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4b41f10bf964a52083ca25e3', 'name': 'Management Concepts', 'location': {'address': '8230 Leesburg Pike', 'lat': 38.917718390552814, 'lng': -77.22928520467556, 'labeledLatLngs': [{'label': 'display', 'lat': 38.917718390552814, 'lng': -77.22928520467556}], 'distance': 192, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8230 Leesburg Pike', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4ef1ec1e0aaf88e5615ec929', 'name': 'Tysons smiles', 'location': {'lat': 38.918329394861715, 'lng': -77.22966207551303, 'labeledLatLngs': [{'label': 'display', 'lat': 38.918329394861715, 'lng': -77.22966207551303}], 'distance': 131, 'postalCode': '22102', 'cc': 'US', 'city': 'Mc Lean', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['Mc Lean, VA 22102', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d178941735', 'name': "Dentist's Office", 'pluralName': "Dentist's Offices", 'shortName': "Dentist's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '59c957443d479165762bcdd0', 'name': 'Tyson Smiles', 'location': {'address': '8230 Leesburg Pike', 'lat': 38.919207, 'lng': -77.22908, 'labeledLatLngs': [{'label': 'display', 'lat': 38.919207, 'lng': -77.22908}], 'distance': 182, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8230 Leesburg Pike', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d178941735', 'name': "Dentist's Office", 'pluralName': "Dentist's Offices", 'shortName': "Dentist's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '516da187e4b0cde23af8e617', 'name': 'ClearChoice Dental Implant Center', 'location': {'address': '8219 Leesburg Pike Ste 100', 'lat': 38.91662, 'lng': -77.230805, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91662, 'lng': -77.230805}], 'distance': 235, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8219 Leesburg Pike Ste 100', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d178941735', 'name': "Dentist's Office", 'pluralName': "Dentist's Offices", 'shortName': "Dentist's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4d91184b9acaa1434a2be0f0', 'name': 'American Sleep Medicine', 'location': {'address': '8300-8398 Boone Blvd', 'lat': 38.917305999999996, 'lng': -77.232763, 'labeledLatLngs': [{'label': 'display', 'lat': 38.917305999999996, 'lng': -77.232763}], 'distance': 213, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8300-8398 Boone Blvd', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d177941735', 'name': "Doctor's Office", 'pluralName': "Doctor's Offices", 'shortName': "Doctor's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4c9ce9aa46978cfadc89927f', 'name': 'Dr Widder Plastic Surgery center', 'location': {'address': '8230 Leesburg Pike #630', 'lat': 38.9181629, 'lng': -77.2294684, 'labeledLatLngs': [{'label': 'display', 'lat': 38.9181629, 'lng': -77.2294684}], 'distance': 153, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8230 Leesburg Pike #630', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d177941735', 'name': "Doctor's Office", 'pluralName': "Doctor's Offices", 'shortName': "Doctor's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_', 'suffix': '.png'}, 'primary': True}], 'venuePage': {'id': '163842076'}, 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4de4f4b9fa7651589f39c77e', 'name': 'Nova Orthopaedics & Sports Medicine Center', 'location': {'address': '8206 Leesburg Pike Ste 409', 'lat': 38.91746316051401, 'lng': -77.22851691525908, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91746316051401, 'lng': -77.22851691525908}], 'distance': 263, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8206 Leesburg Pike Ste 409', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d177941735', 'name': "Doctor's Office", 'pluralName': "Doctor's Offices", 'shortName': "Doctor's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4cc831f994e1a09337f1958b', 'name': "Tyson's Dental Associates", 'location': {'address': '8230 Boone Blvd', 'lat': 38.91590698442994, 'lng': -77.23049102857144, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91590698442994, 'lng': -77.23049102857144}, {'label': '?', 'lat': 38.916003, 'lng': -77.230249}], 'distance': 317, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8230 Boone Blvd', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d178941735', 'name': "Dentist's Office", 'pluralName': "Dentist's Offices", 'shortName': "Dentist's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4ddb98acd22d22fb7c806a45', 'name': 'Widder Plastic Surgery Center', 'location': {'address': '8230 Leesburg Pike Ste 630', 'lat': 38.9180828, 'lng': -77.2293411, 'labeledLatLngs': [{'label': 'display', 'lat': 38.9180828, 'lng': -77.2293411}], 'distance': 167, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8230 Leesburg Pike Ste 630', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d177941735', 'name': "Doctor's Office", 'pluralName': "Doctor's Offices", 'shortName': "Doctor's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4d2c771c3c795481b143f19b', 'name': 'PNC Bank Regional HQ', 'location': {'address': '8229 Boone Blvd', 'lat': 38.91664874211628, 'lng': -77.23093633391139, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91664874211628, 'lng': -77.23093633391139}], 'distance': 231, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8229 Boone Blvd', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4bb9dec5cf2fc9b67ed5a002', 'name': 'Billy Casper Golf', 'location': {'address': '12700 Sunrise Valley Dr Ste 300', 'lat': 38.91706569553659, 'lng': -77.23220028730582, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91706569553659, 'lng': -77.23220028730582}], 'distance': 207, 'postalCode': '20191', 'cc': 'US', 'city': 'Reston', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['12700 Sunrise Valley Dr Ste 300', 'Reston, VA 20191', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4f8f4586e4b072703f29e60f', 'name': 'Dr Balzarett Vienna', 'location': {'lat': 38.91771623304002, 'lng': -77.22853936948849, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91771623304002, 'lng': -77.22853936948849}], 'distance': 247, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d177941735', 'name': "Doctor's Office", 'pluralName': "Doctor's Offices", 'shortName': "Doctor's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4f2310e41081923bac067831', 'name': 'VisionFoundry', 'location': {'address': '8300 Boone Blvd Ste 640', 'crossStreet': '123 & Route 7', 'lat': 38.91666484101062, 'lng': -77.23227739334106, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91666484101062, 'lng': -77.23227739334106}], 'distance': 250, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8300 Boone Blvd Ste 640 (123 & Route 7)', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4df6160bfa76abc3d8752a9e', 'name': 'Angel, Inc.', 'location': {'address': '8219 Leesburg Pike', 'lat': 38.91706756149644, 'lng': -77.23053656761503, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91706756149644, 'lng': -77.23053656761503}], 'distance': 190, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8219 Leesburg Pike', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4e949408823129fb51e47fc9', 'name': 'Koons Automotive Companies', 'location': {'address': '2000 Chain Bridge Rd', 'lat': 38.91941118770635, 'lng': -77.23371575017141, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91941118770635, 'lng': -77.23371575017141}, {'label': '?', 'lat': 38.918975, 'lng': -77.234621}], 'distance': 239, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['2000 Chain Bridge Rd', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4bfe841c2b83b7131beea998', 'name': 'Criterion Systems', 'location': {'address': '8330 Boone Blvd', 'crossStreet': 'Chain Bridge Rd.', 'lat': 38.917305999999996, 'lng': -77.232763, 'labeledLatLngs': [{'label': 'display', 'lat': 38.917305999999996, 'lng': -77.232763}], 'distance': 213, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8330 Boone Blvd (Chain Bridge Rd.)', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4bfd33fd8992a593cfb8abb0', 'name': 'Bruce W. Jay, DDS', 'location': {'address': '8230 Leesburg Pike', 'lat': 38.918234, 'lng': -77.229392, 'labeledLatLngs': [{'label': 'display', 'lat': 38.918234, 'lng': -77.229392}], 'distance': 156, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8230 Leesburg Pike', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d178941735', 'name': "Dentist's Office", 'pluralName': "Dentist's Offices", 'shortName': "Dentist's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_', 'suffix': '.png'}, 'primary': True}], 'venuePage': {'id': '33892244'}, 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4b91377bf964a520c2aa33e3', 'name': 'Booz Allen Hamilton - Auditorium', 'location': {'lat': 38.92049167634611, 'lng': -77.23295154267349, 'labeledLatLngs': [{'label': 'display', 'lat': 38.92049167634611, 'lng': -77.23295154267349}], 'distance': 254, 'postalCode': '22102', 'cc': 'US', 'city': 'Mc Lean', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['Mc Lean, VA 22102', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4c35ace5a0ced13ac11b1a6e', 'name': 'Drs. Delgado & Kuzmik', 'location': {'address': '8230 Leesburg Pike', 'lat': 38.91828690598748, 'lng': -77.22917137211851, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91828690598748, 'lng': -77.22917137211851}], 'distance': 173, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8230 Leesburg Pike', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d178941735', 'name': "Dentist's Office", 'pluralName': "Dentist's Offices", 'shortName': "Dentist's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4fa1785ee4b0200a4b494c97', 'name': 'Fairfax Internal', 'location': {'lat': 38.91677702862873, 'lng': -77.23274384865378, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91677702862873, 'lng': -77.23274384865378}], 'distance': 259, 'postalCode': '22102', 'cc': 'US', 'city': 'Mc Lean', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['Mc Lean, VA 22102', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d177941735', 'name': "Doctor's Office", 'pluralName': "Doctor's Offices", 'shortName': "Doctor's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_doctorsoffice_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4ca0e98319e4236a2ab36589', 'name': 'Emergent LLC', 'location': {'address': '8133 Leesburg Pike', 'crossStreet': 'Gallows Road', 'lat': 38.916601, 'lng': -77.230785, 'labeledLatLngs': [{'label': 'display', 'lat': 38.916601, 'lng': -77.230785}, {'label': '?', 'lat': 38.91675, 'lng': -77.23105}], 'distance': 237, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8133 Leesburg Pike (Gallows Road)', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '528a202911d2a9f7bdf1878b', 'name': "QSSI Tyson's Corner", 'location': {'address': '8720 Greensboro Dr', 'lat': 38.92054428701159, 'lng': -77.23063320761007, 'labeledLatLngs': [{'label': 'display', 'lat': 38.92054428701159, 'lng': -77.23063320761007}], 'distance': 206, 'cc': 'US', 'city': 'McLean', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8720 Greensboro Dr', 'McLean, VA', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '523b2c0811d2a985a46b2be8', 'name': 'Tercon Consulting', 'location': {'address': '8300 Boone Blvd Ste 610', 'lat': 38.917305999999996, 'lng': -77.232763, 'labeledLatLngs': [{'label': 'display', 'lat': 38.917305999999996, 'lng': -77.232763}], 'distance': 213, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8300 Boone Blvd Ste 610', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '520a3806498e5e0680387901', 'name': 'Mythics, Inc.', 'location': {'address': '8219 Leesburg Pike', 'lat': 38.91737549889648, 'lng': -77.23012238189625, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91737549889648, 'lng': -77.23012238189625}], 'distance': 171, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8219 Leesburg Pike', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '512e67f3e4b05f7d49753bc7', 'name': '8306 Old Courthouse Road, Vienna, VA. 22182', 'location': {'lat': 38.91757, 'lng': -77.23285, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91757, 'lng': -77.23285}], 'distance': 199, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4c87b78b47cc224bcc9bb39f', 'name': '8219 Leesburg Pike', 'location': {'lat': 38.917171, 'lng': -77.22978897, 'labeledLatLngs': [{'label': 'display', 'lat': 38.917171, 'lng': -77.22978897}], 'distance': 206, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4f4ba6fde4b0922ac8915bf7', 'name': 'ICS Serka', 'location': {'lat': 38.91789170835508, 'lng': -77.22935333242084, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91789170835508, 'lng': -77.22935333242084}], 'distance': 176, 'postalCode': '22102', 'cc': 'US', 'city': 'Mc Lean', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['Mc Lean, VA 22102', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4b587993f964a520805928e3', 'name': 'Lee Hecht Harrison', 'location': {'lat': 38.91771742198828, 'lng': -77.23350164939134, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91771742198828, 'lng': -77.23350164939134}], 'distance': 236, 'cc': 'US', 'state': 'Virginia', 'country': 'United States', 'formattedAddress': ['Virginia', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4ef2322ee3003ccf84688e80', 'name': 'Microlink', 'location': {'address': '8330 Boone Blvd', 'crossStreet': 'Boone Blvd', 'lat': 38.916949712006414, 'lng': -77.23246879384874, 'labeledLatLngs': [{'label': 'display', 'lat': 38.916949712006414, 'lng': -77.23246879384874}], 'distance': 230, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8330 Boone Blvd (Boone Blvd)', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '50943923e4b000bd1fb3865d', 'name': 'Social Media Operations Command Center', 'location': {'lat': 38.91717, 'lng': -77.232812, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91717, 'lng': -77.232812}], 'distance': 228, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '516eadf4498e504a898d1beb', 'name': 'Clear Choice Dental Implants Center', 'location': {'lat': 38.916545098063125, 'lng': -77.23043673644335, 'labeledLatLngs': [{'label': 'display', 'lat': 38.916545098063125, 'lng': -77.23043673644335}], 'distance': 248, 'cc': 'US', 'city': 'Tysons Corner', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['Tysons Corner, VA', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d178941735', 'name': "Dentist's Office", 'pluralName': "Dentist's Offices", 'shortName': "Dentist's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '4f902b5ae4b072703fe9da44', 'name': 'TLC Dentistry', 'location': {'address': '8206 Leesburg Pike Ste 308', 'lat': 38.9175543, 'lng': -77.2284164, 'labeledLatLngs': [{'label': 'display', 'lat': 38.9175543, 'lng': -77.2284164}], 'distance': 265, 'postalCode': '22182', 'cc': 'US', 'city': 'Tysons Corner', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8206 Leesburg Pike Ste 308', 'Tysons Corner, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d178941735', 'name': "Dentist's Office", 'pluralName': "Dentist's Offices", 'shortName': "Dentist's Office", 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/medical_dentist_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# {'id': '53ecc0b7498e41f20f593c3c', 'name': 'PSI Health Insurance', 'location': {'address': '8206 Leesburg Pike Ste 305', 'lat': 38.91761041031516, 'lng': -77.2283541219681, 'labeledLatLngs': [{'label': 'display', 'lat': 38.91761041031516, 'lng': -77.2283541219681}], 'distance': 267, 'postalCode': '22182', 'cc': 'US', 'city': 'Vienna', 'state': 'VA', 'country': 'United States', 'formattedAddress': ['8206 Leesburg Pike Ste 305', 'Vienna, VA 22182', 'United States']}, 'categories': [{'id': '4bf58dd8d48988d124941735', 'name': 'Office', 'pluralName': 'Offices', 'shortName': 'Office', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_', 'suffix': '.png'}, 'primary': True}], 'referralId': 'v-1586536460', 'hasPerk': False}
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
CENTER
# Out:
# lat    38.874451
# lng   -77.203971
# dtype: float64

# %%
PLACES[['lat', 'lng']].min()
# Out:
# lat    38.804836
# lng   -77.431099
# dtype: float64

# %%
print(type(PLACES[['lat','lng']].max().values))
# Out:
# <class 'numpy.ndarray'>
